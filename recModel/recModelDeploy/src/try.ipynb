# %%
#from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
# import os
# import logging
# #from src.bookEmbeddings import load_book_embeddings
import sagemaker
import boto3
import io
import pandas as pd
import json

# %%
x = """{\"instances\": [{\"authors\": 0,\"user_id\": [1],\"liked_books\": ["The Great Gatsby","The Catcher in the Rye","To Kill a Mockingbird"],\"disliked_books\": ["The Hobbit","The Lord of the Rings"],\"liked_genres\": ["Fiction","Literature","Classics"],\"disliked_genres\": ["Fantasy","Fantasy"],\"liked_authors\": ["F. Scott Fitzgerald","J.D. Salinger","Harper Lee"],\"disliked_authors\": ["J.R.R. Tolkien","J.K. Rowling"],\"liked_ratings\": [5,4,3], \"disliked_ratings\": [1,2],\"categories\": 0,\"description\": 0,\"target_book\": 0,\"target_book_rating\": 0,\"keep_title\": [],\"keep_authors\": [],\"keep_categories\": [],\"remove_title\": [],\"remove_authors\": [],\"remove_categories\": []}]}"""

# %%
type(json.loads(x))
# Out:
# dict

# %%
type(x)
# Out:
# str

# %%
# bucket = 'w210recsys'
# key = 'model/recModel/modelFiles/book_embeddings.npy'

# role = sagemaker.get_execution_role()
# sm_session = sagemaker.Session()
s3 = boto3.client('s3')
# Out:
# [03/20/25 17:18:52] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=891466;file:///home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=78610;file:///home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/botocore/credentials.py#1352\1352]8;;\

# %%
# s3.download_file(bucket, key, 'book_embeddings.npy')

from stringLookup import string_lookup

s3_bucket = "w210recsys"

#s3://w210recsys/model/recModel/modelFiles/book_authors_vocab_layer.json

#book_author_vocab_layer = string_lookup(s3.get_object(Bucket=s3_bucket, Key="model/recModel/modelFiles/book_authors_vocab_layer.json")['Body'].read().decode('utf-8'))
test = s3.get_object(Bucket=s3_bucket, Key="model/recModel/modelFiles/book_authors_vocab_layer.json")['Body'].read().decode('utf-8')

# book_author_vocab_layer = json.loads(book_author_vocab_layer['Body'].read().decode('utf-8'))
# book_author_vocab_layer

# %%
x = json.loads(test)
x.keys()
# Out:
# dict_keys(['vocabulary', 'oov_token'])

# %%
book_author_vocab_layer
#len(list(book_author_vocab_layer.keys()))
# Out:
# {'Julie Strain': 1,
#  'Philip Nel': 2,
#  'David R. Ray': 3,
#  'Veronica Haddon': 4,
#  'Edward Long': 5,
#  'Everett Ferguson': 6,
#  'Miriam Allen De Ford': 7,
#  'Lee Blessing': 8,
#  'Mary Fabyan Windeatt': 9,
#  'Steven Wardell': 10,
#  'Camillia Fawzi El-Solh Judy Mabro': 11,
#  'Armando Salda A-Mora': 12,
#  'Evelyn B. Christensen': 13,
#  'Allen Gersho Robert M. Gray': 14,
#  'Frank Owen': 15,
#  'Barry Crump': 16,
#  'Fiona Cownie': 17,
#  'Rochelle Gurstein': 18,
#  'Kenneth H. Cooper': 19,
#  'Ruth Allman': 20,
#  'Robert Kane': 21,
#  'Dorling Kindersley Publishing Staff Jonathan Bousfield Matthew Willis': 22,
#  'Howard Hill': 23,
#  'DK': 24,
#  'Sonia Rivera-Valdes': 25,
#  'Arthur J. Droge': 26,
#  'Donald Laming': 27,
#  'John T. Morse': 28,
#  'Steve Richardson': 29,
#  'John Adrian': 30,
#  'National Portrait Gallery': 31,
#  'Rupert Fike': 32,
#  'E. B. Harvey': 33,
#  'Stefan Draminski': 34,
#  'Raymond Charles Barker': 35,
#  '': 36,
#  'Lorenz Books Margaret Malone Paul Jackson': 37,
#  'Kristin Ramsdell': 38,
#  'National Geographic Maps': 39,
#  'Jeffrey M. Bale': 40,
#  'Karen Cummings': 41,
#  'Marie Weil Michael S. Reisch Mary L. Ohmer': 42,
#  'May Mcgoldrick': 43,
#  'Kayode J. Fakinlede': 44,
#  'Sydney Walker': 45,
#  'Ryan Jones': 46,
#  'Tedd Benson': 47,
#  'George Oakes Jaquith Georgetta Jaquith Walker': 48,
#  'Elizabeth Sinclair': 49,
#  'Sue Walters': 50,
#  'J. G. A. Pocock': 51,
#  'Cara Delevingne': 52,
#  'Kevin Valgaeren': 53,
#  '"Nena ONeill" "George ONeill"': 54,
#  'John Ruskin': 55,
#  'Thomas F. Torrance': 56,
#  'United States. Coast Guard': 57,
#  'Dorie N. Van Stone Erwin W. Lutzer': 58,
#  'Alan Nourse': 59,
#  'Peter Bander': 60,
#  'John Morrone': 61,
#  'Mary J. Getten': 62,
#  'Evan Gerstmann Matthew Justin Streb': 63,
#  'Jerry Baker': 64,
#  'Mark Graham': 65,
#  'Dennis B. Klein': 66,
#  'Tom Williams': 67,
#  'Douglas Terman': 68,
#  'John Doody Kim Paffenroth Kevin L. Hughes': 69,
#  'Graham Robson': 70,
#  '"Kerri ODonnell"': 71,
#  'Ramon Llull Kenneth Leech Edgar Allison Peers': 72,
#  'L.J. Smith': 73,
#  'Non Ishida James Dalgety': 74,
#  'Richard Hofstadter': 75,
#  'Kelly Bulkeley Patricia Bulkley': 76,
#  'Karel Eckschlager Klaus Danzer': 77,
#  'Bill Franz': 78,
#  'L. V. H. Crosby': 79,
#  'Ellis Spear': 80,
#  'Jeroen C. J. M. Van den Bergh': 81,
#  'Anthony Capella': 82,
#  'Thomas Chastain': 83,
#  'Charles J. Bodenstab': 84,
#  'Tad Tuleja': 85,
#  'Jim Fay': 86,
#  'Frances Parkinson Keyes': 87,
#  'Julian Winston': 88,
#  'Thomas Powell': 89,
#  'K. H. Scheer Wendayne Ackerman F. J. Ackerman': 90,
#  'Peter Kenez': 91,
#  'M. Uyehara': 92,
#  'Michelle Bain': 93,
#  'BroadStreet Publishing Group LLC': 94,
#  'Timothy Zahn': 95,
#  'Oscar Wilde': 96,
#  'Mercer Mayer': 97,
#  'Christine Feehan': 98,
#  'Norvell': 99,
#  'Tonie Holt Valmai Holt': 100,
#  'Stephen L. Pearce Richard D. Bushnell': 101,
#  'Louis Berkhof': 102,
#  'Patricia Cornwell': 103,
#  'Ann Radcliffe': 104,
#  'Rob Dückers Karin van Lieverloo Museum Het Valkhof Nijmegen': 105,
#  'Kristine Stiles Peter Selz': 106,
#  'Barbara Melosh': 107,
#  'Joann Sfar': 108,
#  'Sloan Bill': 109,
#  'John Malatich': 110,
#  'Robert Ross Smith': 111,
#  'Candi Adermatt': 112,
#  'John McPherson': 113,
#  'Frederik Pohl Jack Williamson': 114,
#  'Walter B. Meigs Robert F. Meigs': 115,
#  'David Hatcher Childress': 116,
#  'David Herbert Donald': 117,
#  'Henry Hazlitt': 118,
#  'Rick Hautala': 119,
#  'Bertrand Russell': 120,
#  'Sandra Markle': 121,
#  'Donald Denoon Mark Hudson Gavan McCormack Tessa Morris-Suzuki': 122,
#  'Ted J. Kaptchuk': 123,
#  'Laurie Lawlor': 124,
#  'Horst Keller': 125,
#  'Charles J. Finger': 126,
#  'Sharon De Vita': 127,
#  'Michel LEVIEUX': 128,
#  'Robert T. Rood James S. Trefil': 129,
#  'John William Ransom Taylor Paul Jackson': 130,
#  'Katherine Ramsland': 131,
#  'Ansel F. Hall': 132,
#  'Bruce M. Nash Allan Zullo': 133,
#  'Henry Abramson': 134,
#  'Timur Kuran': 135,
#  'George A. Ellis': 136,
#  'Jacques Derrida': 137,
#  'Jack Higgins': 138,
#  'Rose Estes': 139,
#  'Paul Beyerl': 140,
#  'Dewar Designs LLC': 141,
#  'Nathanael West': 142,
#  'Marie Hammontree': 143,
#  'Charles Kingsley': 144,
#  'José Hernández': 145,
#  'Leroy Garrett': 146,
#  'Amanda Ashley': 147,
#  'Arnold Schwarzenegger Douglas Kent Hall': 148,
#  'Wallace Welch': 149,
#  'Bruce Holmes': 150,
#  'Cyril Connolly': 151,
#  'Karen Judson': 152,
#  'Nathaniel Hawthorne': 153,
#  'Stephen L. Corson': 154,
#  'Jerry Mungadze Phd': 155,
#  'Alfred Carl Hottes': 156,
#  'William Stanley Jevons': 157,
#  'Martin Frank': 158,
#  'Jon Aristides': 159,
#  'Patrick Jennings': 160,
#  'Michael D. Tuttle': 161,
#  'Shaw': 162,
#  '"Patrick Geoffrey ONeill"': 163,
#  'Max Blumenthal': 164,
#  'Eric Jensen': 165,
#  'Damien Bona': 166,
#  'Johannes Itten': 167,
#  'Robert Milner': 168,
#  'Dean Dudley Amanda Telford Claire Stonehouse Louisa Peralta Matthew Winslade': 169,
#  'Carol Belanger Grafton': 170,
#  'Lisa Oakley': 171,
#  'Jeffrey McAndrew': 172,
#  'Alanna Morland': 173,
#  'Gerry Nagtzaam': 174,
#  'Phillip A. Laplante': 175,
#  'Ralph Mayer': 176,
#  'Shawn Robbins Leanna Greenaway': 177,
#  'Christine Ramsey Lyman Henry Lyman': 178,
#  'Robert F. Jones': 179,
#  'Tsung Hwa Jou': 180,
#  'Tanith Lee': 181,
#  'Brian L. Weiss': 182,
#  'John Schaefer': 183,
#  'Don Holm': 184,
#  'Juliet Marillier': 185,
#  'E. Batschelet': 186,
#  'Seymour Reit': 187,
#  'Zelig Pliskin': 188,
#  'Arie de Geus': 189,
#  'David Lundberg': 190,
#  'Janey Trishon': 191,
#  'Philip José Farmer': 192,
#  'Clarissa Lightheart': 193,
#  'David Wiltse': 194,
#  'Zdena Kapral': 195,
#  'Caren Caraway': 196,
#  'Julia McMeans': 197,
#  'Klutz': 198,
#  'Daniel Chartier': 199,
#  'John Herd Thompson': 200,
#  'Malcolm Andrew Ronald Waldron': 201,
#  'Robert Caper': 202,
#  'W. W. Jacobs': 203,
#  'James Thurber': 204,
#  'Los Angeles County Museum of Art Mary L. Levkoff': 205,
#  'Diane Schmidt': 206,
#  'Sue Bender': 207,
#  'Brannon Jason S. Brown Eric Grover John': 208,
#  '"Justine OFlynn"': 209,
#  'James A. Herrick': 210,
#  'Jeff Bower Joseph Sheehan Clay Davenport Gary Huckabay Chris Kahrl Rany Jazayerli Keith Law Mat Olkin Dave Pease': 211,
#  'Winston Leonard Spencer Churchill': 212,
#  'Jean Marzollo Walter Wick': 213,
#  'Felix Maurice Hippisley Markham': 214,
#  'Ann Ann Howey': 215,
#  'Rosamunde Pilcher': 216,
#  'Margaret Parent Lutz': 217,
#  'Herbert Lockyer': 218,
#  'Raven Kaldera Tannin Schwartzstein': 219,
#  'Mark Podolsky': 220,
#  'F. Vernon Chandler': 221,
#  'Hershel Shanks': 222,
#  'Johann Wolfgang von Goethe': 223,
#  'Judith C. Brown': 224,
#  'Linnea Smith': 225,
#  'Barbara Campbell': 226,
#  'Kylie Brant': 227,
#  'Madison Smartt Bell': 228,
#  'John A. Jackman Bastiaan M. Drees': 229,
#  'Harriet Martineau': 230,
#  'Henry Vogel Jackson Guice': 231,
#  'John McDonald John P. McDonald': 232,
#  'DK Travel': 233,
#  'Abraham Lincoln': 234,
#  'Thomas Paine': 235,
#  'Geoffrey Bourton Keene': 236,
#  'Howard Zinn': 237,
#  'Dylan Jones Mehrdad Tamiz': 238,
#  'Vinson Brown': 239,
#  'Max Brand': 240,
#  'William Lawrence Neuman': 241,
#  'Clark Coolidge': 242,
#  'Betty Antunes de Oliveira': 243,
#  'John C. Maxwell': 244,
#  'Jere Bishop Franco': 245,
#  'Elizabeth Winthrop': 246,
#  'Gretchen Holbrook Gerzina': 247,
#  'Nazli Kibria': 248,
#  'James P. Brosnan': 249,
#  'Gale Group': 250,
#  'Lonely Planet Michael Benanav Joe Bindloss Lindsay Brown Stuart Butler Mark Elliott Paul Harding Trent Holden Anirban Mahapatra Bradley Mayhew Daniel McCrohan John Noble Kevin Raub Sarina Singh Iain Stewart Isabella Noble': 251,
#  'Wally Armbruster': 252,
#  'Derek Mckay H.M. Scott': 253,
#  'Peter M. Haas': 254,
#  'Edgar Allan Poe': 255,
#  'Forrest E. Baird': 256,
#  'William Barnaby Faherty': 257,
#  'Frank Daignault': 258,
#  'Frank Gee Patchin': 259,
#  'J Ludwig D Tongway K Hodgkinson D Freudenberger J Noble': 260,
#  'Dailey News of Los Angeles Los Angeles Daily News Press-Telegram': 261,
#  'Travel Journals Canals of Amsterdam': 262,
#  'Ellen Margolis Lissa Tyler Renaud': 263,
#  'Simon Winchester': 264,
#  'Aldren A. Watson': 265,
#  'Joanna Scott': 266,
#  'Major LaCaritilie Magic Carpet Books': 267,
#  'Edna Deu Pree Nelson': 268,
#  'Anne Cholawo': 269,
#  'Barbara Schave Klein': 270,
#  'Tres Iniciados': 271,
#  'David K. Wright': 272,
#  'James W. Moore': 273,
#  'Franklin G. Miller Luana Colloca Ted J. Kaptchuk': 274,
#  'Peter Terrel': 275,
#  'Foshanta L. Garth Deanita H. McCall': 276,
#  'Michael Francis Gilbert': 277,
#  'Jurgen Haacke': 278,
#  'Gwen Bristow': 279,
#  'Marcello Barbieri': 280,
#  'Hope Lourie Killcoyne': 281,
#  'William E. Boyce Richard C. DiPrima': 282,
#  'Richard T. Wright Bernard J. Nebel': 283,
#  'Edward John Trelawny': 284,
#  'Ken Renshaw': 285,
#  'Annalees Lim': 286,
#  'Abby J Stewart': 287,
#  'Ronald R. Brill': 288,
#  'Peter Ballingall': 289,
#  'Malvina Cathleen Kaveny': 290,
#  'Daniel Goleman': 291,
#  'Brad Schepp Debra Schepp': 292,
#  'Clarence Day': 293,
#  'Will Durant Ariel Durant': 294,
#  'Charles Dickens': 295,
#  'William Albert Robinson': 296,
#  'SyberVision Systems Inc': 297,
#  'Peter McWilliams': 298,
#  'Sadie Wernick Hurwitz': 299,
#  'Ogden Nash': 300,
#  'Susan Meddaugh': 301,
#  'Robert Masters': 302,
#  'Vanessa Jakeman Clare McDowell': 303,
#  'Owen Egerton': 304,
#  'Giuliana Cavallini Caroline Holland': 305,
#  'Søren Kierkegaard': 306,
#  'Ernest Miller Hemingway J.W.F. Werumeus Buning': 307,
#  'Nelson Lee': 308,
#  'Linda Lee Mike Lee': 309,
#  'Sterling Watson': 310,
#  'Stanley Morison Cambridge University Press': 311,
#  'F. Tennyson (Fryniwyd Tennyson) Jesse': 312,
#  'Harj Gill': 313,
#  'Greg A. Gerrie': 314,
#  'Jeffrey Carl Rona': 315,
#  'Emma Jensen': 316,
#  'Ed McCarthy Mary Ewing-Mulligan': 317,
#  'Gary A Langenwalter': 318,
#  'Edward J. Bardon': 319,
#  'Sotero Agboton': 320,
#  'Donna Fason': 321,
#  'Ronda L. Brulotte Michael A. Di Giovine': 322,
#  'Ana Guadalupe Valenzuela Zapata Gary Paul Nabhan': 323,
#  'AGATHA. CHRISTIE': 324,
#  'Patrick Sweeney': 325,
#  'Martin Urban': 326,
#  'Alamo Area Library System (Tex.)': 327,
#  'LaUna Huffines': 328,
#  'Tsi-gziou Li Roman Rome': 329,
#  'C. Edwin Baker': 330,
#  'Brian H. Jones': 331,
#  'Jean-Paul Sartre': 332,
#  'Charles F. Levinthal': 333,
#  'Jacqueline S. Thursby': 334,
#  'William F. Buckley Jr.': 335,
#  'Juliet Koprowska': 336,
#  'Ruth Daggett LEINHAUSER': 337,
#  'William Leach': 338,
#  'Pamela Horn': 339,
#  'Motoo Yamakura': 340,
#  'Topol': 341,
#  'Corrin Strong': 342,
#  'Donald Cline': 343,
#  'Christopher Buckley': 344,
#  'Lynette Vinet': 345,
#  'Gregory J. Higby': 346,
#  'Hendrickson Publishers': 347,
#  'Jim Pipe': 348,
#  'Joan E. Kaiser': 349,
#  'Jiddu Krishnamurti': 350,
#  'James Claude Thomson': 351,
#  'Lawrence Langel': 352,
#  'Neal Frisby': 353,
#  'Francis Brown Barton Edward Hinman Sirich': 354,
#  'Dorothy Canfield': 355,
#  'United States. Soil Conservation Service': 356,
#  'Robert Marshall': 357,
#  'Jason Thompson': 358,
#  'Gabriel Biderman Tim Cooper': 359,
#  'Bharat Thakur': 360,
#  'Tom Birdseye Bill Klein': 361,
#  'Piers Anthony': 362,
#  'Paul Oliver': 363,
#  'Barbara B. Lackritz': 364,
#  'Mary Calhoun': 365,
#  'Melissa Dodd': 366,
#  'North Carolina. Department of Community Colleges. Curriculum Laboratory. Audio-Visual Education': 367,
#  'Kenneth Cloke': 368,
#  'Andrew Jaffe Lisa Tysen Sven-Olof Lindblad': 369,
#  'David Remnick': 370,
#  'Debra H. Lewin Ellen de Haan Haan': 371,
#  'Samuel Hynes Anne Matthews Nancy Caldwell Sorel': 372,
#  'Rae Crossmon': 373,
#  'Eugenio Montale': 374,
#  'Betty Jane Wagner Mark Larson': 375,
#  'Ron Dunn': 376,
#  'Jean M. Auel': 377,
#  'DK PUBLISHING Dorling Kindersley': 378,
#  'Lynn Cullen': 379,
#  'H. Rider Haggard': 380,
#  'Deborah Coultrip-Davis Young Sook Ramsay': 381,
#  'Alan J. Flusser': 382,
#  'Robert J. Reimold': 383,
#  'Emma Lathen': 384,
#  'Amy Baker': 385,
#  'Stephen Cox': 386,
#  'Richard K. Bernstein': 387,
#  'Mary Ronald': 388,
#  'Frederick Schiller Faust': 389,
#  'Joel S. A. Hayward': 390,
#  'Llewellyn Vaughan-Lee Irina Tweedie': 391,
#  'Nemata Amelia Blyden': 392,
#  'Eric Nadel': 393,
#  'Cynthia Tunstall': 394,
#  'Primo Levi': 395,
#  'Cassie Edwards': 396,
#  'Howard E. Cook': 397,
#  'Dandi Daley Mackall Barry Gott': 398,
#  'Ronda Armitage David Armitage': 399,
#  'Bob Wilson': 400,
#  'Ronald Hutton': 401,
#  'Stephen R. Rementer Bruce N. Eimer': 402,
#  'Bryan Mellonie': 403,
#  'Dave Hughes': 404,
#  'Jean Calvin': 405,
#  'Malcolm L. Hunter': 406,
#  'Vern Gambetta Steve Odgers': 407,
#  'Andrea Sutcliffe': 408,
#  'Stormie Omartian': 409,
#  'Isaac Kramnick Robert Laurence Moore R. Laurence Moore': 410,
#  'L. J. Smith': 411,
#  'Lolo Pedro': 412,
#  'Richard Boyer Richard Owen Boyer Herbert Montfort Morais': 413,
#  'Al Anderson': 414,
#  'Lester David': 415,
#  'Michael Stipe Tom Gilroy Douglas Martin': 416,
#  'Marian Wright Edelman': 417,
#  'Origins Publications': 418,
#  'John A. Keel': 419,
#  'Stephen J. Pitti': 420,
#  'Tom Watts': 421,
#  'Stephanie Newell': 422,
#  'Ben B. Fischer': 423,
#  'Chad Harbach': 424,
#  'Star LaBranche': 425,
#  'John Kremer': 426,
#  'Edgar Rice Burroughs': 427,
#  'Gordon Swanborough Peter M. Bowers': 428,
#  'Vincent F. Seyfried William Asadorian': 429,
#  'David N. Laband George McClintock': 430,
#  'Scott Straus': 431,
#  'Dave Chaffey': 432,
#  'Vivian DeRusha Quantz': 433,
#  'Kimberly K. Ballard': 434,
#  'John E. Hesselgreaves': 435,
#  'Janet Farrar Stewart Farrar': 436,
#  'Joanna Frueh': 437,
#  'Dilip K. Das Rajaram K. Prabhudesai': 438,
#  'Jamaica Kincaid (pseud. van Elaine Potter Richardson)': 439,
#  'Edward Raventon Paul Horsted': 440,
#  'Jean Giono': 441,
#  'Marshall T. Rose': 442,
#  'Alan Dean Foster': 443,
#  'M. H. Alsuwaiyel': 444,
#  'Robert D. SaintLaurent': 445,
#  'Gerhold K. Becker': 446,
#  'Erle Stanley Gardner': 447,
#  'Paris Reidhead': 448,
#  'Charlie Smith': 449,
#  'Robert Rutland': 450,
#  'David Pierce': 451,
#  'Dean Koontz': 452,
#  'Nickole Brown Judith Taylor': 453,
#  'Michelin Travel Publications (Firm)': 454,
#  'Mary-Elaine Jacobsen': 455,
#  'Harold Schechter Jonna Gormely Semeiks': 456,
#  'Robert Houston': 457,
#  'Scott Adams Martín Perazzo': 458,
#  'Shawn Amador': 459,
#  'Ruth Wind': 460,
#  'Dian Layton': 461,
#  'Amy Nathan': 462,
#  'James W. Williams': 463,
#  'D. A. Cruse': 464,
#  'David R. Starbuck': 465,
#  'Melanie Jackson': 466,
#  'Robin C. Pennell': 467,
#  'あい・矢沢': 468,
#  'Philippa Gregory': 469,
#  'John Matthews': 470,
#  'Charles R. Swindoll': 471,
#  'Caroline Reynolds': 472,
#  'Timothy McMahon': 473,
#  'Joe Kelsey': 474,
#  'Iris Origo': 475,
#  'John Galsworthy': 476,
#  'Christopher Coker': 477,
#  'John Arquilla David Ronfeldt': 478,
#  'George P. Donehoo': 479,
#  'Lillian Too': 480,
#  'Tania Gabrielle': 481,
#  'Ray Robinson Allen Winold': 482,
#  'Karen Rauch Carter': 483,
#  'Claus Westermann': 484,
#  'Leonard Pitt': 485,
#  'Elaine Showalter': 486,
#  'H. George Shoffner Susan Shelly Robert Cooke': 487,
#  'Jacques Derrida Musée du Louvre': 488,
#  'Bergen Evans': 489,
#  'Maurits Cornelis Escher J. L. Locher': 490,
#  'Lady Barker': 491,
#  'Eric Roberts': 492,
#  'William Gilmore Simms': 493,
#  'Bernard Malamud': 494,
#  'Wally Jay': 495,
#  'J. Daniel Gifford': 496,
#  'Sandra Benitez': 497,
#  'Hugh Lofting': 498,
#  'Hilary St. George Saunders MC': 499,
#  'Ambrose Bierce': 500,
#  'Cheryl Angelina Koehler': 501,
#  'Patrick Spielman': 502,
#  'Bible English English Standard Collins Anglicised ESV Bibles': 503,
#  'Debra Webb': 504,
#  'Bowker Editorial Staff R R Bowker Publishing Bowker': 505,
#  'Frances Mayes': 506,
#  'James Baldwin': 507,
#  'Coleman Barks': 508,
#  'Tama Starr': 509,
#  'Norma Ruth Wilson': 510,
#  'Thomas Hardy': 511,
#  'James M. Dyet': 512,
#  'Joachim E. Fest': 513,
#  'Elizabeth Bluehorse': 514,
#  'Raymond M. Corbin': 515,
#  'Vivian C. Cadbury': 516,
#  'Bruce S. Feiler': 517,
#  'John F Schostak Taylor & Francis Group': 518,
#  'Solomon Northup': 519,
#  'Larry Niven Poul Anderson Paul Chafe Hal Colebatch': 520,
#  'Ashok Swamy': 521,
#  'Samira Rao': 522,
#  'Charles M. Coleman': 523,
#  'Susan Fletcher': 524,
#  'Richard Russo': 525,
#  'J. P. Forget': 526,
#  'J.C. Suares': 527,
#  'John Boman': 528,
#  'Peter Kingsley': 529,
#  'Deborah Blaz': 530,
#  '"Thomas DArcy McGee"': 531,
#  'Library of Congress. Copyright Office': 532,
#  'Phaedra Hise': 533,
#  'Marie Winn': 534,
#  'Jack Kerouac': 535,
#  'Elizabeth Bowen': 536,
#  'Archibald Alexander Hodge': 537,
#  'Jane Nelsen': 538,
#  'Ken Bazyn': 539,
#  'Steve Sullivan': 540,
#  'Andrew Vladimirov Konstantin Gavrilenko Andrei Mikhailovsky': 541,
#  'Ramona Jablonski': 542,
#  'R. D. Blackmore': 543,
#  'Zitkala Sa': 544,
#  'Abraham Merritt': 545,
#  'James Kilgo': 546,
#  'United States. Army Map Service. Library. Book and Periodical Branch': 547,
#  'NA NA': 548,
#  'Dennis William Hauck': 549,
#  'Bill Nichols': 550,
#  'Virginia Hamilton E. L. Konigsburg "Robert C. OBrien"': 551,
#  'United States. Congress. House': 552,
#  'Nancy Friday': 553,
#  'David McCann': 554,
#  'Steven J. Milloy': 555,
#  'Jennifer Knust Tommy Wasserman': 556,
#  'Joseph Butler': 557,
#  'Paxton Quigley': 558,
#  'F. Marion Crawford Lee Weinstein': 559,
#  'Daniel Pechoin': 560,
#  'Jeannette Hardy Lake Douglas': 561,
#  'Julie Ganz': 562,
#  'John Gray Jerusha Hull McCormack': 563,
#  'John Locke Francis Bacon': 564,
#  'David Zolt': 565,
#  'Suzanne Willis Zoglio': 566,
#  'Barbara Barstow Judith Riggle': 567,
#  'Foster Furcolo': 568,
#  'Sir Malcolm D. Evans Sofia Galani': 569,
#  'Juliet E.K. Walker': 570,
#  'James Lam': 571,
#  'Patrick Olivelle': 572,
#  'Christopher Lasch': 573,
#  'Vikas Khatri': 574,
#  'Gayle Rosenwald Smith J.D. Sally Abrahms': 575,
#  'Nina Harrington': 576,
#  'Moshe Halbertal Donniel Hartman': 577,
#  'Tom Brosnahan': 578,
#  'Daniela Krien': 579,
#  'JJA Harwood': 580,
#  'Smithsonian Institution Mimi Dietrich National Museum of American History (U.S.)': 581,
#  'Chevy Stevens': 582,
#  'George Herbert Orchard': 583,
#  'Richard W. Farwell': 584,
#  'K. Louwman Willem Kromkamp': 585,
#  'Rose Gough Kerr': 586,
#  'Steven R. Selengut': 587,
#  'Nicola Cornick': 588,
#  'Elizabeth Sabrinsky Foster': 589,
#  'Tom Betsy Jim Keogh': 590,
#  'Michele Borba': 591,
#  'Mark Strand': 592,
#  'Robert Rosenstone': 593,
#  'Robert Follansbee': 594,
#  'Pierre Bourdieu': 595,
#  'Lyn Cote': 596,
#  'James Morrow': 597,
#  'Kelly L. Murdock': 598,
#  'Joseph Scudder Chamberlain': 599,
#  'Marieke Blokland': 600,
#  'Mykel Board': 601,
#  'Donald A. Low': 602,
#  'Laurence E. Lynn Jr. Carolyn J. Heinrich Carolyn J. Hill': 603,
#  'Lynn Ellen Doxon': 604,
#  'James L. Crenshaw': 605,
#  'Samuel Bronfman Professor of Democratic Dusiness Enterprise-Manangement Donald C Hambrick': 606,
#  'Peter Ustinov': 607,
#  'Vernon Rosco CARSTENSEN': 608,
#  'Taylor Marsh': 609,
#  'Mark Philip Bradley': 610,
#  'Henry S. Olcott': 611,
#  'John Garrett': 612,
#  'Lisa Aronson Fontes': 613,
#  'Patricia Rich Dana Hines': 614,
#  'Barbara Gordon': 615,
#  'Con Price': 616,
#  'Gerald Durrell': 617,
#  'Lorraine Johnston': 618,
#  'Sandor Nagyszalanczy': 619,
#  'Prof Joanna Bourke Joanna Bourke': 620,
#  'Terence Hanbury White': 621,
#  'Teiji Itō': 622,
#  'Thomas Hoover': 623,
#  'Denise Dietz': 624,
#  'Harry Pidgeon': 625,
#  'Victor Thaddeus': 626,
#  'Vincent A. McCarthy': 627,
#  'Gerald R Pieters': 628,
#  'Globe': 629,
#  'Aggrawal Ajay': 630,
#  'John Alec Baker': 631,
#  'Robert Chapman': 632,
#  'Clifford A. Hull Steven R. Perkins Tracy Barr': 633,
#  'William S. Burroughs': 634,
#  'Elliott Leyton': 635,
#  'Melinda Roth': 636,
#  'Eve Curie': 637,
#  'Andrew Porter': 638,
#  'John Dean': 639,
#  'Derek Howard Aldcroft Richard Rodger': 640,
#  'Robert L. Kapitzke': 641,
#  'David B. Thomson': 642,
#  'Eric M Bergerud': 643,
#  'Thomas Gordon': 644,
#  'Rick Polizzi': 645,
#  'Aaron Kipnis': 646,
#  'Vanessa Watson': 647,
#  'Basil Davidson': 648,
#  'Oasis Press/PSI Research': 649,
#  'Dorothy Canfield Fisher': 650,
#  'Rand McNally and Company (NA) Rand McNally and Company': 651,
#  'Michael A. Godfrey': 652,
#  'John Okell Anna Allott': 653,
#  'Virginia Ryan': 654,
#  'Irmgard Schloegl': 655,
#  'Edward Evan Evans-Pritchard': 656,
#  'Maan Meyers': 657,
#  'Jan Eaton': 658,
#  'Edward II (King of England)': 659,
#  'Butch Harmon': 660,
#  'Eugenia C. DeLamotte Voltairine De Cleyre': 661,
#  'George S. Lensing': 662,
#  'General George C. Kenney': 663,
#  'Julia Straub': 664,
#  'Daniel Donnelly': 665,
#  'Alfredo Matilla Ivan Silen': 666,
#  'Monica Hughes': 667,
#  'John Christopher': 668,
#  'Steve Derne Steve Derné': 669,
#  'Robert C. Merton': 670,
#  'William Reed': 671,
#  'Dianna Booher': 672,
#  'Daniel Lazare': 673,
#  'Stephen King': 674,
#  'Max N. Andrews': 675,
#  'Gloria J. Burgess': 676,
#  'Nick Wood Nicholas Wood': 677,
#  'Henry George': 678,
#  'Stefano Calicchio': 679,
#  'Madeleine Wickham': 680,
#  'M. Russell Ballard': 681,
#  'Richard E. Eby': 682,
#  'William Shakespeare': 683,
#  'Robert C. Sprung Simone Jaroniec': 684,
#  'TSR Inc TSR Inc. Staff': 685,
#  'Walter Bagehot': 686,
#  'William Heffernan': 687,
#  'Gladys Conklin': 688,
#  'Geraldine Flanagan': 689,
#  'D. Yogi Goswami Frank Kreith': 690,
#  'Robert J. Randisi': 691,
#  'Louise Penny': 692,
#  'Robert Kirkwood': 693,
#  'John Henry Newman': 694,
#  'Anne Baker': 695,
#  'Mable Hoffman Gar Hoffman': 696,
#  'Dorothy Corkille Briggs': 697,
#  'Charles Manson Nuel Emmons': 698,
#  'Ken Catran': 699,
#  'David Weber': 700,
#  'Gwendolyn Leick': 701,
#  'Jean Doresse': 702,
#  'Mireille Mentre': 703,
#  'Charles Wesley Lowry': 704,
#  'Leonard Yanow': 705,
#  'Elmer E. Gaede Naomi Gaede-Penner': 706,
#  'Ruth Megaw': 707,
#  'William Cheung Ted Wong': 708,
#  'Trisha R. Thomas': 709,
#  'Edmund Saunders "Great Britain. Court of Kings Bench"': 710,
#  'Mahmood Mamdani': 711,
#  'Alastair Reynolds': 712,
#  'Roger Handy Maureen Erbe Aileen Antonier': 713,
#  'Wilhelm Reich': 714,
#  'Robert Descharnes Gilles Néret Jan Wynsen Marieke Keur Salvador Felipe Jacinto Dalí': 715,
#  '"Patricia M. OConnor"': 716,
#  'Victoria Glendinning': 717,
#  'Lloyd Gardner': 718,
#  'Leon Fradley Whitney': 719,
#  'Lillian Müller John Coleman Jill Gannon': 720,
#  'Ross Bernstein': 721,
#  'George Thomas': 722,
#  'Illuminati Formula': 723,
#  'Nelson Lichtenstein': 724,
#  'Paul A M Van Lange Arie W Kruglanski E Tory Higgins': 725,
#  'Leah Komaiko': 726,
#  'William D. Hassett': 727,
#  'Harald Hoiback': 728,
#  'Norman Bridwell': 729,
#  'Ben M. Baglio': 730,
#  '"Anthony A. DAmato"': 731,
#  'M. L. Stevens': 732,
#  'Rumer Godden': 733,
#  'James Clavell': 734,
#  'Sergius Golowin': 735,
#  'Donald Arthur Wells': 736,
#  'Graal Braun': 737,
#  'Leisure Arts Inc.': 738,
#  'Kazuo Iwamura': 739,
#  'James Huneker': 740,
#  '"Inc. Fodors Travel Publications" "Fodors"': 741,
#  'Allen Rucker': 742,
#  'Franklin W. Dixon': 743,
#  'Bruce Anderson Michael Riordan Linda Goodman': 744,
#  'Rosemary Lunardini': 745,
#  'Nancy Hatch Dupree': 746,
#  'David Trinidad': 747,
#  'Frederick Douglass Michael Meyer': 748,
#  'James Robert Brown': 749,
#  'James Plunkett': 750,
#  'George Beal Simon & Schuster': 751,
#  'Dumas Malone': 752,
#  'Helena Hunting': 753,
#  'William H. Patterson Andrew Thornton': 754,
#  'Sidney Cox': 755,
#  'Marcus Libkind': 756,
#  'Dick Sternberg North American Fishing Club': 757,
#  'Zoe Mellor': 758,
#  'Johann Friedrich Starck W. H. T. Dau William Weedon': 759,
#  'Ruth Miskin': 760,
#  'David Leedom Shaul': 761,
#  'Matthew Linn Dennis Linn': 762,
#  'Gary Lee COLLISON': 763,
#  'Betty Cavanna': 764,
#  'Robert Tallant': 765,
#  'David Morrish Marlene MacCallum': 766,
#  'Margaret Mead': 767,
#  'Joan Robinson': 768,
#  'Rob Walker': 769,
#  'James Charles Raymond': 770,
#  'Francis Bok': 771,
#  'Margaret Coffin': 772,
#  'A. BRAMSON': 773,
#  'Emilie P. Rose': 774,
#  'Vicktor Barrios': 775,
#  'George Berkeley': 776,
#  'Scott Rutherford': 777,
#  'Joanne Rock': 778,
#  'Ross Hair Thomas Ruys Smith': 779,
#  'Pamela J. Sharpe': 780,
#  'Joanna Mansell': 781,
#  'Constantin Stanislavski': 782,
#  'Stephen Giles': 783,
#  'Judith Resnick Lanny Martin Lester': 784,
#  'Mary Wollstonecraft': 785,
#  'Helen Sheumaker': 786,
#  'B. J. Rowley': 787,
#  'Peter Maurice Daly': 788,
#  'Bryanna Clark Grogan': 789,
#  'Gillian Crowther': 790,
#  'Jonathan R. Eller Ray Bradbury William F. Touponce Kent State University Press': 791,
#  'Harry Mazer': 792,
#  'Anne Morand Daniel C. Swan Kevin Smith Sarah Erwin': 793,
#  'Ivan Doig': 794,
#  'Dorothy Carnegie': 795,
#  'Frederick Douglass': 796,
#  'Robert Henry Thouless': 797,
#  'Kin Platt': 798,
#  'Charlotte Kirk Baer Duane E. Ullrey Wilson G. Pond': 799,
#  'Sandra Lee Msc': 800,
#  'Brad Morrell': 801,
#  'M. Chris Fabricant': 802,
#  'A. B. Spellman': 803,
#  'Richard Horsey': 804,
#  'Mitzi Waltz': 805,
#  'Vincent Bugliosi Curt Gentry': 806,
#  'Gerard Kuc': 807,
#  'Yukio Mishima': 808,
#  'A. Redhed': 809,
#  'Laura L. McCullough Brenda M. Tanner': 810,
#  'Horatio Alger': 811,
#  'Richard Trigaux': 812,
#  'Jennifer Blake': 813,
#  'Anne Sinkler Whaley LeClercq': 814,
#  'Constance Scovill Small': 815,
#  'David Halberstam': 816,
#  'Hieremias Drexelius': 817,
#  'Will Shortz': 818,
#  'Gary Greenberg Jerome Tuccille': 819,
#  'Robert Frost': 820,
#  'Eric Flint Richard Roach': 821,
#  'David Chong': 822,
#  'James P. Hogan': 823,
#  'Alejandro Zambra': 824,
#  'Arthur W. Upfield': 825,
#  'Alexander Elder': 826,
#  'Wilson Hope Nelson Andrews Mrs. J. Reaney Kelly': 827,
#  'Jason Byassee': 828,
#  'James Applewhite': 829,
#  'Joseph Cottler': 830,
#  'Rudolf Steiner': 831,
#  'Francie M. Berg': 832,
#  'Melanie Mitchell': 833,
#  'Paul Boyer': 834,
#  'Tobias Matthay': 835,
#  'Leslie F. Brandt': 836,
#  'Helen McLean Abiye Cole': 837,
#  'Jean Vanier': 838,
#  'Wilbur Smith': 839,
#  'Bill Martin Jr. John Archambault': 840,
#  'J. V. Frederick': 841,
#  'Laura Doyle': 842,
#  'Deborah Smith': 843,
#  'Terrell L. Hill': 844,
#  'Anne Perry': 845,
#  'Nancy Ellen Abrams': 846,
#  'John R. Zaller Zaller John R': 847,
#  'Ron Anderson': 848,
#  'Doris L. Ganton': 849,
#  'Robert Wolgemuth': 850,
#  'Krause Publications Inc': 851,
#  'Gary Ferguson': 852,
#  'Larry Christenson': 853,
#  'David Jenness Don Velsey': 854,
#  'Frank Yerby': 855,
#  'A. G. Smith Josie Hazen': 856,
#  'Mercedes Lackey Eric Flint Dave Freer': 857,
#  'David Horowitz': 858,
#  'Erich Kästner': 859,
#  'Arthur Conan Doyle': 860,
#  'Dover': 861,
#  'Jane Sullivan': 862,
#  'Jerrold L. Schecter Leona Schecter': 863,
#  'Frederick R. Sidell William C. Patrick III Thomas R. Dashiell': 864,
#  'Christine Webster': 865,
#  'Hank Hassell': 866,
#  'Michel Chion I. B. Tauris': 867,
#  'Charles Taze Russell': 868,
#  'Jim Harris': 869,
#  'Harry E. Allen Edward J. Latessa Bruce S. Ponder': 870,
#  'Lynette Jensen': 871,
#  'John Banks Valentina Dragan Arthur Jones': 872,
#  'Patricia Telesco Don Waterhawk': 873,
#  'Douglas Robert Nickel Francis Frith': 874,
#  'George Anton Kiraz': 875,
#  'Edward Miller': 876,
#  'Margaret Collins': 877,
#  'Edward Weeks': 878,
#  'Raymond Chandler': 879,
#  'Kevin Phillips': 880,
#  'Peter Simkins': 881,
#  'Terry Pratchett': 882,
#  'Graham Greene': 883,
#  'Catherine Marshall': 884,
#  'Eliga Gould Paul Mapp Carla Gardina Pestana': 885,
#  'Anon E. Mouse': 886,
#  'Charles Frederick Johnson': 887,
#  'John Richardson': 888,
#  'Barbara Johnson Witcher': 889,
#  'Jax Peters Lowell': 890,
#  'Nella Bielski': 891,
#  'Sherry Monahan': 892,
#  'Michael Ruhlman': 893,
#  'Henri Nouwen': 894,
#  'E. Ashley Rooney Peter Gerhard Stampfl': 895,
#  'Robert Mills Gagné Walter W. Wager Katharine Golas John M. Keller': 896,
#  'Robert Pinsky': 897,
#  'United States. Congress. House. Committee on Armed Services. Subcommittee on Research and Development': 898,
#  'Exam Master Corporation': 899,
#  'Dudley Young': 900,
#  'Margot Sunderland': 901,
#  'Alvin Pettus Myron Blosser': 902,
#  'Anthony J. Bocchino David A. Sonenshein': 903,
#  'Matthew Bishop': 904,
#  'Maksim Gorky L. e. Gorky': 905,
#  'Anna Downes': 906,
#  'Gordon Mitchell': 907,
#  'Rachel Eagen': 908,
#  'Paul Evan Lehman': 909,
#  'Ken Wardius Barb Wardius': 910,
#  'Ralph M. Kovel Terry H. Kovel': 911,
#  'Insight Guides': 912,
#  'Melissa Hemsley': 913,
#  'Arthur Gordon': 914,
#  'Bartley Gorman with Peter Walsh': 915,
#  'William Hall': 916,
#  'Jane Larson Wipf': 917,
#  'Kim Newman': 918,
#  'Margaret L. Johnson Owen Crabb Arthur A. Opfer Randall R. Thiel Frederik R. Mottola': 919,
#  'Martyn Hurn': 920,
#  'Robert L. Herbert': 921,
#  'David S. Kenik': 922,
#  'Kerry Patterson Joseph Grenny Ron McMillan Al Switzler': 923,
#  'Daniel Lombardo': 924,
#  'Karen Essex James L. Swanson': 925,
#  'Wilcox Ella Wheeler': 926,
#  'Elisabeth Smith': 927,
#  'William Empson': 928,
#  'Lon Schleining': 929,
#  'Douglas Hill': 930,
#  'Leonard Feinberg': 931,
#  'A. J. Finn': 932,
#  'Ravindra Kumar': 933,
#  'Ruby Ann Boxcar': 934,
#  'Ed Tittel Kim Lindros': 935,
#  'Eleanor Gates': 936,
#  'Astrid Holleeder': 937,
#  'Charles Simic': 938,
#  'Burton Goodman': 939,
#  'Noel Perrin': 940,
#  'Jeanine Cummins': 941,
#  'Pierre Van Paassen': 942,
#  'Robert Shea': 943,
#  'Jennifer Ogle Theo Witsell Johnnie Gentry': 944,
#  'David Morrell': 945,
#  'Nancy Gift': 946,
#  'Sigmund Freud': 947,
#  'Angie Williams Jon F. Nussbaum': 948,
#  'Stacey Levine': 949,
#  'Deanna Swaney Myra L. Shackley': 950,
#  'William Kabzinski': 951,
#  '一茶·小林': 952,
#  'Dale Wasserman': 953,
#  'Randy Garbin Teri Dunn': 954,
#  'Edmond John': 955,
#  'Lloyd J. Harris': 956,
#  'Simonetta Carr': 957,
#  'Jonathan Harbour': 958,
#  'A. G. Smith Activity Books': 959,
#  'Sister Souljah': 960,
#  'Richard Reitzenstein': 961,
#  'Victoria and Albert museum libr': 962,
#  'Maryann Chach Reagan Fletcher': 963,
#  'J. P. Polidoro': 964,
#  'A.C. Chang': 965,
#  'Richard M. Hodgetts Donald F. Kuratko': 966,
#  'Karen Rivers': 967,
#  'Robert James Maddox': 968,
#  'Gail Howard': 969,
#  'Yigal Levin': 970,
#  'C. H. Spurgeon': 971,
#  'Arnold Houbraken Gezine Brit': 972,
#  'Thomas Edward Lawrence': 973,
#  'Rosemary Sassoon': 974,
#  'Joseph Devlin': 975,
#  'Richard Barrett': 976,
#  'Lucy Larcom': 977,
#  'Eduardo Sguiglia': 978,
#  'Wilke Collins': 979,
#  'Maureen Witt': 980,
#  'Jeanne Shaw Virginia Erhardt': 981,
#  'Frances Hesselbein Marshall Goldsmith Iain Somerville': 982,
#  'William Wesley Peterson': 983,
#  'Shelly R. Wilson': 984,
#  'Abigail Van Buren': 985,
#  'J. Dale Miller': 986,
#  'John V. Dennis': 987,
#  'Philip Van Doren Stern': 988,
#  'Clive Gifford': 989,
#  'Serge Obolensky': 990,
#  'Mina García Soormally': 991,
#  'Rozzi Bazzani': 992,
#  'Dennis Freeborn': 993,
#  'Tomas Larsson': 994,
#  'Dave Pelzer': 995,
#  'Tony Wood Bill Gunston': 996,
#  'Philip Schaff': 997,
#  'Val Kilmer': 998,
#  'Roger Elwood': 999,
#  'Daniel Dolgin Ph.D': 1000,
#  ...}

# %%
from bookEmbeddings import load_book_embeddings
# Out:
# /home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# [03/15/25 13:10:20] INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=198785;file:///home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=565280;file:///home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/botocore/credentials.py#1352\1352]8;;\
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/zfenton/.config/sagemaker/config.yaml

# %%
s3_bucket = "w210recsys"
aws_book_embeddings_path = "model/recModel/modelFiles/book_embeddings.npy" 
aws_books_df_path = "model/recModel/modelFiles/books_df.csv"

# %%
x = load_book_embeddings(s3_bucket, aws_book_embeddings_path, aws_books_df_path)
print(type(x))
# Out:
#                     INFO     Found credentials in shared credentials file: ~/.aws/credentials   ]8;id=884678;file:///home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/botocore/credentials.py\credentials.py]8;;\:]8;id=38166;file:///home/zfenton/.cache/pypoetry/virtualenvs/210-api-9v8zSIhV-py3.11/lib/python3.11/site-packages/botocore/credentials.py#1352\1352]8;;\
# Successfully loaded objects from S3: response, books_df
#
# Loaded book_embeddings to buffer: <_io.BytesIO object at 0x7f975bcc85e0>
# Successfully loaded book_embeddings to books_df {'ResponseMetadata': {'RequestId': '484T10A7K1VB92CF', 'HostId': 'wo9Cb69cUZbLKSipZd2y78sG5TB7wvtPVlGZNe/zAF405DEllMVD2Zd4sqiLwHF4yShnFTeVpX35vG33/41gZWvcogh49z+GpRL0WHE1WOM=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'wo9Cb69cUZbLKSipZd2y78sG5TB7wvtPVlGZNe/zAF405DEllMVD2Zd4sqiLwHF4yShnFTeVpX35vG33/41gZWvcogh49z+GpRL0WHE1WOM=', 'x-amz-request-id': '484T10A7K1VB92CF', 'date': 'Sat, 15 Mar 2025 20:10:23 GMT', 'last-modified': 'Wed, 12 Mar 2025 05:51:49 GMT', 'etag': '"210f529b58863ddea214242c29a1324a-22"', 'x-amz-checksum-crc32': 'SoVkAQ==-22', 'x-amz-checksum-type': 'COMPOSITE', 'x-amz-server-side-encryption': 'AES256', 'x-amz-version-id': 'I.TO6B8phS0Ou.xPPnOeM001w51PdyTX', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '181078647', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'AcceptRanges': 'bytes', 'LastModified': datetime.datetime(2025, 3, 12, 5, 51, 49, tzinfo=tzutc()), 'ContentLength': 181078647, 'ETag': '"210f529b58863ddea214242c29a1324a-22"', 'ChecksumCRC32': 'SoVkAQ==-22', 'ChecksumType': 'COMPOSITE', 'VersionId': 'I.TO6B8phS0Ou.xPPnOeM001w51PdyTX', 'ContentType': 'binary/octet-stream', 'ServerSideEncryption': 'AES256', 'Metadata': {}, 'Body': <botocore.response.StreamingBody object at 0x7f975bcbb130>}
# <class 'pandas.core.frame.DataFrame'>

# %%
books_df = s3.get_object(Bucket=s3_bucket, Key=aws_books_df_path)
books_df_ = io.BytesIO(books_df['Body'].read())

# %%
# Example: Assuming 'buffer' is your BytesIO object containing CSV data
books_df_.seek(0)  # Move to the start of the buffer
df = pd.read_csv(books_df_)
print(df.head())

# Save as CSV file
df.to_csv("output.csv", index=False)

# %%
response = s3.get_object(Bucket=s3_bucket, Key=aws_book_embeddings_path)
buffer = io.BytesIO(response['Body'].read())

# %%
df['embeddings'] = [embed for embed in np.load(buffer)]

# %%
df['embeddings'].iloc[0]

# %%
x.get('embeddings')

# %%
y = np.vstack(x['embeddings'].values)

# %%
s3_bucket = "w210recsys"
aws_book_embeddings_path = "model/recModel/modelFiles/book_embeddings.npy" 
aws_books_df_path = "model/recModel/modelFiles/books_df.csv"

# Load book embeddings
#load_book_embeddings(s3_bucket, aws_book_embeddings_path, aws_books_df_path)

# %%
response = s3.get_object(Bucket=s3_bucket, Key=aws_book_embeddings_path)

# %%
def load_book_embeddings(s3_bucket, aws_book_embeddings_path, aws_books_df_path):

    s3 = boto3.client('s3')

    response = s3.get_object(Bucket=s3_bucket, Key=aws_book_embeddings_path)
    # Download the books_df file from S3 into memory
    books_df = s3.get_object(Bucket=s3_bucket, Key=aws_books_df_path)
    print("Successfully loaded objects from S3: response, books_df")
    print(" ")
    print("Deleting objects from memory")
    del response
    del books_df
    print("Successfully deleted objects from memory")
    
    return("success")

# %%
load_book_embeddings(s3_bucket, aws_book_embeddings_path, aws_books_df_path)
